# %% [markdown]
# <a href="https://colab.research.google.com/github/ioi2027/vocabuddy-group-8/blob/main/VocaBuddy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi github and colab")
# Out:
# hi github and colab

# %%
words = '''
gadget
n.小裝置／小玩意
underestimate
v.低估
uncharted
adj.未知的／未探索的
defective
adj.有缺陷的／故障的
doomed
adj.注定失敗的
erode
v.侵蝕／逐漸破壞
bluntly
adv.直言不諱地
depreciate
v.貶值
obsolete
adj.過時的／淘汰的
option
n.選擇／替代方案
options
n.選擇（複數）
neutral
adj.中立的／不表態的
implication
n.影響／後果
implications
n.影響／後果（複數）
tension
n.緊張關係／拉扯
mature
v.成熟
matured
adj.已成熟的
dubious
adj.可疑的／價值存疑的
trailblazer
n.先驅／開路者
take a gamble
idiom.冒險一試
collect dust
idiom.閒置／積灰塵
catch on
phr.v.流行起來／被大眾接受
fall into the trap
phr.掉進陷阱
be stuck with
phr.被套牢／甩不掉
shift to
phr.v.轉向
early adopter
n.嘗鮮者／早期採用者
revenue
n.營收
revenues
n.營收（複數）
tactic
n.策略／手段
release
n./v.上市／發行
significantly
adv.大幅地
furthermore
adv.此外
rapidly
adv.迅速地
cautious
adj.謹慎的
caution
n.小心／謹慎
regrettably
adv.遺憾地
discontinue
v.停產／停止支援
discontinued
adj.已停產的／已停止支援的
pricey
adj.昂貴的
overpriced
adj.定價過高的
reluctant
adj.不情願的
compete
v.競爭
competing
adj.相互競爭的
dominate
v.主導／主宰
dominating
adj.佔優勢的
refrain from
phr.v.克制／避免去做
virtually
adv.幾乎／實際上
worthless
adj.毫無價值的
activate
v.啟動
permission
n.許可
acknowledge
v.承認／告知
privacy
n.隱私
data-collection
n.資料蒐集
status
n.地位／身份
willingness
n.意願
congratulate
v.恭喜
warlord
軍閥（名詞）
utilize
利用；運用（動詞）
laying it on a bit thick
表現得有點太誇張；過度渲染
petitioned
請願；正式請求（動詞）
discrimination
歧視；差別待遇（名詞）
residents
居民（名詞）
superstitious
迷信的（形容詞）
incorporated
納入；合併；使成為公司（動詞）
nostalgic
懷舊的（形容詞）
manor
莊園；領地宅邸（名詞）
intimidating
令人生畏的；嚇人的（形容詞）
committee
委員會（名詞）
generous
慷慨的；大方的（形容詞）
spry
活潑敏捷的（形容詞）
kendo
劍道（名詞）
half-assing
敷衍了事；馬馬虎虎地做（動詞）
a sight to behold
值得一看的景象
obediently
順從地；服從地（副詞）
refined
優雅的；精緻的（形容詞）
sleeve
袖子（名詞）
flutter
飄動；拍動翅膀（動詞／名詞）
emphasizing
強調（動詞）
chatter
喋喋不休；閒聊（動詞／名詞）
milling about
四處閒逛；走來走去
chiming
發出鐘聲；插話附和（動詞）
accompanies
陪伴；伴隨（動詞）
entranced
著迷的；被迷住的（形容詞）
spontaneously
自發地；自然地（副詞）
regret
後悔；遺憾（動詞／名詞）
inherit
繼承（動詞）
moron
笨蛋；蠢貨（名詞）
gremlin
小精靈；搗蛋鬼（名詞）
bickering
爭吵；鬥嘴（動詞／名詞）
enshrined
奉為神聖；正式載入（動詞）
raffle
抽獎（名詞／動詞）
katana
武士刀（名詞）
stabbed
刺；刺傷（動詞）
gleams
閃耀；微光（動詞／名詞）
luster
光澤；光彩（名詞）
draw you in
吸引你；使你投入
dedicated
專注的；奉獻的（形容詞）
aforementioned
前述的；上述的（形容詞）
grin
咧嘴笑（動詞／名詞）
grunts
咕噥聲；發出哼聲（動詞／名詞）
exertion
用力；勞累（名詞）
draw the sword
拔劍
macho
大男人主義的；男子氣概強的（形容詞／名詞）
thighs
大腿（名詞）
skeptical
懷疑的（形容詞）
stern glare
嚴厲的瞪視（名詞）
contestants
參賽者（名詞）
intimidating
令人生畏的；嚇人的（形容詞）
charade
做戲；假裝（名詞）
head priest
大祭司；神職領袖（名詞）
initial impression
第一印象
bullseye
正中紅心；命中目標（名詞）
struck out
失敗；遭淘汰；三振出局
underestimate
低估（動詞）
flirt
調情；打情罵俏（動詞／名詞）
boulder
巨石（名詞）
hilt
刀柄；劍柄（名詞）
crackle
劈啪作響（動詞／名詞）
firm grip
牢固的握持
muttering
喃喃自語（動詞／名詞）
revenue
收入；營收（名詞）
master
大師；主人（名詞）／精通（動詞）
bewilderment
困惑；茫然（名詞）
revenge
報復；復仇（名詞／動詞）
mere
僅僅的；只不過的（形容詞）
spectacle
壯觀景象；奇觀（名詞）
acquaintance
熟人；認識的人（名詞）
nonplussed
困惑的；不知所措的（形容詞）
unfit
不適合的；不健康的（形容詞）
wield
揮舞；使用（動詞）
tugged
拉扯；拖曳（動詞）
styrofoam
保麗龍；聚苯乙烯泡棉（名詞）
interpretation
解釋；詮釋（名詞）
bestowed
授予；賜予（動詞）
majesty
威嚴；陛下（名詞）
lump
塊；腫塊（名詞）
feat
壯舉；功績（名詞）
deduction
推論；扣除（名詞）
insincere
不真誠的；虛偽的（形容詞）
provoking
挑釁的；引起反應的（形容詞）
ruckus
騷動；喧鬧（名詞）
compensation
補償；賠償（名詞）
indulge
縱容；沉溺於（動詞）
grief
悲傷；悲痛（名詞）
stubborn
固執的；頑強的（形容詞）
privileges
特權；特殊待遇（名詞）
warped
扭曲的；變形的（形容詞）
pedestal
基座；（比喻）受人崇拜的地位（名詞）
staring
盯著看（動詞）
starring
主演；擔任主角（動詞）
engaged
已訂婚的；忙碌的；投入的（形容詞）
out of nowhere
突然地；不知從何處地
betrothed
已訂婚的；未婚夫／未婚妻（形容詞／名詞）
fiancée
未婚妻（名詞）
fancy
喜愛；想要（動詞）華麗的；高級的（形容詞）
interrupting
打斷；中斷（動詞）
consequences
後果（名詞）
sleep a wink
睡著片刻；闔眼休息
principles
原則；信念（名詞）
mortal
終有一死的；凡人的（形容詞／名詞）
handy
方便的；有用的（形容詞）
retrospect
回顧；追溯（名詞）
instincts
本能；直覺（名詞）
ingrained
根深蒂固的（形容詞）
retract
撤回；收回（動詞）
debate
辯論；討論（名詞／動詞）
feigning composure
假裝鎮定
resist
抵抗；忍住（動詞）
entertaining
有趣的；娛樂性的（形容詞）
intention
意圖；目的（名詞）
pajamas
睡衣（名詞）
accompany
陪伴；伴隨（動詞）
doubt
懷疑（動詞／名詞）
aloof
冷淡的；疏遠的（形容詞）
freeloading
白吃白喝；佔便宜（動詞／名詞）
thud
砰的一聲；重擊聲（名詞）
blankly
茫然地；呆呆地（副詞）
mugged
搶劫（動詞）
preoccupied
心不在焉的；全神貫注於某事的（形容詞）
squish
壓扁；擠壓（動詞／名詞）
assent
同意；贊成（動詞／名詞）
exceptionally
特別地；異常地（副詞）
consist of
由……組成
fond
喜愛的；喜歡的（形容詞）
compromising
妥協的；有損形象的（形容詞）
preferable
較好的；更可取的（形容詞）
groggy
昏昏沉沉的（形容詞）
lingering
持續存在的；流連不去的（形容詞）
acquaintance
熟人；認識的人（名詞）
bodyguards
保鑣（名詞）
substitution
替代；代換（名詞）
awkward
尷尬的；笨拙的（形容詞）
pardon
原諒；赦免（動詞／名詞）
stubborn
固執的（形容詞）
ordeal
嚴酷考驗；磨難（名詞）
curt
簡短無禮的（形容詞）
grumbling
抱怨；發牢騷（動詞／名詞）
broadcast rerun
重播節目（名詞）
pathetic
可憐的；糟糕的（形容詞）
particular
特定的；特別的（形容詞）
fraud
詐騙；騙子（名詞）
displeasing
令人不快的（形容詞）
appealing
吸引人的（形容詞）
persuade
說服（動詞）
investigate
調查（動詞）
rendezvous
會面；約會地點（名詞）
pissed
生氣的（形容詞，較口語）
ticked off
惱火的；生氣的（形容詞）
hypocritical
虛偽的；偽善的（形容詞）
involuntary
非自願的；不由自主的（形容詞）
inclines
傾向於；斜坡（動詞／名詞）
rustling
沙沙作響（動詞／名詞）
clump
一叢；一團（名詞）
paralyze
使癱瘓；使無法行動（動詞）
twig
細枝；嫩枝（名詞）
primal
原始的；本能的（形容詞）
treacherous
危險的；背信棄義的（形容詞）
potential
潛力；潛在的（名詞／形容詞）
graze
擦傷；吃草（動詞）
lance
長矛（名詞）
tumbling
翻滾；跌倒（動詞）
assailed
猛烈攻擊；抨擊（動詞）
momentary
短暫的；瞬間的（形容詞）
desperate
絕望的；孤注一擲的（形容詞）
sheet
床單；薄片；紙張（名詞）
bandages
繃帶（名詞）
laceration
撕裂傷（名詞）
bruises
瘀青；挫傷（名詞）
gawk
呆看；目瞪口呆地盯著看（動詞）
unsettling
令人不安的（形容詞）
sting
刺痛；叮咬（動詞／名詞）
amiss
不對勁的；有問題的（形容詞）
relieved
鬆了一口氣的；安心的（形容詞）
aghast
驚駭的；嚇呆的（形容詞）
assure
向……保證；使確信（動詞）
ordeal
磨難；嚴酷考驗（名詞）
fuzzy
模糊的；毛茸茸的（形容詞）
battered
傷痕累累的；破舊的（形容詞）
banged up
受傷的；撞壞的（形容詞）
shred
碎片；撕碎（名詞／動詞）
examined
檢查；檢驗（動詞）
breezy
微風徐徐的；輕鬆愉快的（形容詞）
strip
長條；剝除；脫去（名詞／動詞）
harassment
騷擾（名詞）
shrunk
縮小；縮水（動詞）
groaning
呻吟；抱怨（動詞／名詞）
insist
堅持；堅決要求（動詞）
fright
恐懼；驚嚇（名詞）
incriminated
使牽連入罪；指控（動詞）
taint
玷污；污染（動詞／名詞）
unattended
無人照顧的；無人看管的（形容詞）
concur
同意；意見一致（動詞）
preface
前言；作為開場白（名詞／動詞）
regardless
不管怎樣；無論如何（副詞）
dusk
黃昏（名詞）
indeed
確實；的確（副詞）
suffice
足夠；足以（動詞）
sludge
爛泥；污泥（名詞）
indiscriminately
不加區分地；不分青紅皂白地（副詞）
despises
鄙視；厭惡（動詞）
hatred
仇恨（名詞）
denote
表示；象徵（動詞）
trail off
逐漸變小聲；漸漸停止
trait
特徵；性格特質（名詞）
exclusive
獨有的；排他的（形容詞）
rumor
謠言（名詞）
potency
效力；力量（名詞）
beastly
野獸般的；可怕的（形容詞）
dwelt
居住；停留於（動詞）
purifying
淨化；潔淨（動詞）
ominous
不祥的；不好的預兆的（形容詞）
twinge
一陣刺痛；一絲感覺（名詞）
tend to
傾向於；往往會
casual
隨意的；非正式的（形容詞）
formalities
禮節；正式程序（名詞）
sirloin
沙朗牛排（名詞）
croquettes
可樂餅（名詞）
certain
確定的；某個的（形容詞）
brood
沉思；孵蛋（動詞）
approve
同意；批准（動詞）
cabbage
高麗菜；捲心菜（名詞）
freebie
免費贈品（名詞）
labor
勞動；工作（名詞／動詞）
stealth
隱密行動；潛行（名詞）
nobility
貴族階級；高尚品格（名詞）
one's bearing
某人的儀態；舉止（名詞）
persona
人物形象；人格面具（名詞）
dazzling
耀眼的；令人驚艷的（形容詞）
rehearsal
排練（名詞）
utmost
最大的；極度的（形容詞）
torn
撕裂的；糾結的（形容詞）
sew
縫製（動詞）
stitches
縫線；縫合針（名詞）
amateur
業餘愛好者；業餘的（名詞／形容詞）
shoddy
粗製濫造的；劣質的（形容詞）
involved
涉及的；複雜的（形容詞）
heirloom
傳家寶（名詞）
burden
負擔；重擔（名詞／動詞）
fanfare
盛大宣傳；號角齊鳴（名詞）
stroll
散步（動詞／名詞）
shivers
顫抖；寒顫（名詞）
bedridden
臥病在床的（形容詞）
guarantee
保證；擔保（名詞／動詞）
casualties
傷亡人數；受害者（名詞）
ease
減輕；容易（動詞／名詞）
burden
負擔；重擔（名詞／動詞）
stated
陳述；說明（動詞）
retrospect
回顧；追溯（名詞）
drastic
激烈的；極端的（形容詞）
celebrity
名人（名詞）
reverence
敬畏；尊敬（名詞）
afflicted
受折磨的；受苦的（形容詞）
plague
瘟疫；困擾（名詞／動詞）
doomed
註定失敗的；注定滅亡的（形容詞）
salvation
救贖；拯救（名詞）
gladly
樂意地；高興地（副詞）
relinquish
放棄；交出（動詞）
resolve
決心；解決（名詞／動詞）
screw this
去他的；我不幹了
pathetic
可憐的；糟糕的（形容詞）
chivalry
騎士精神（名詞）
pretense
假裝；藉口（名詞）
cling
緊抓；依戀（動詞）
perish
死亡；毀滅（動詞）
deprecating
自貶的；反對的（形容詞）
vitality
活力；生命力（名詞）
wane
衰退；減弱（動詞）
inevitability
必然性（名詞）
whim
一時興起；心血來潮（名詞）
volition
意志；自主決定（名詞）
convince
說服；使相信（動詞）
groan
呻吟；抱怨（動詞／名詞）
sulky
鬧彆扭的；悶悶不樂的（形容詞）
pedant
學究；賣弄學問的人（名詞）
sash
腰帶；肩帶（名詞）
faint
昏倒；微弱的（動詞／形容詞）
sentience
知覺能力；感知力（名詞）
imbued
使充滿；灌輸（動詞）
wreathed
環繞；覆蓋（動詞）
falter
遲疑；蹣跚（動詞）
chill
寒冷；使冷卻（名詞／動詞）
tentacle
觸手（名詞）
grooves
凹槽；溝紋（名詞）
scramble to one's feet
匆忙站起來
send (someone) sprawling
把（某人）撞倒在地
deflecting
使偏轉；轉移（動詞）
deftly
熟練地；靈巧地（副詞）
fend
抵擋；應付（動詞）
reverie
白日夢；幻想（名詞）
scramble back
慌忙退後
ferocious
兇猛的；殘暴的（形容詞）
writhe
扭動；翻滾掙扎（動詞）
thicket
灌木叢（名詞）
chuckle
輕聲笑（動詞／名詞）
shabby
破舊的；寒酸的（形容詞）
stiffly
僵硬地；拘謹地（副詞）
shame
羞愧；恥辱（名詞）
degenerate
墮落的；退化（形容詞／動詞）
reckless
魯莽的；不顧後果的（形容詞）
leech
水蛭；吸血鬼般的人（名詞）
sidelines
場邊；旁觀位置（名詞）
grief
悲傷；悲痛（名詞）
lectured
訓斥；講授（動詞）
pretend
假裝（動詞）
explicitly
明確地；直白地（副詞）
non-perishable
不易腐壞的；耐存放的（形容詞）
cupboard
櫥櫃；碗櫥（名詞）
'''

w = words.split('\n')[1:]
english = w[::2]
chinese = w[1::2]
english,chinese
# Out:
# (['gadget',
#   'underestimate',
#   'uncharted',
#   'defective',
#   'doomed',
#   'erode',
#   'bluntly',
#   'depreciate',
#   'obsolete',
#   'option',
#   'options',
#   'neutral',
#   'implication',
#   'implications',
#   'tension',
#   'mature',
#   'matured',
#   'dubious',
#   'trailblazer',
#   'take a gamble',
#   'collect dust',
#   'catch on',
#   'fall into the trap',
#   'be stuck with',
#   'shift to',
#   'early adopter',
#   'revenue',
#   'revenues',
#   'tactic',
#   'release',
#   'significantly',
#   'furthermore',
#   'rapidly',
#   'cautious',
#   'caution',
#   'regrettably',
#   'discontinue',
#   'discontinued',
#   'pricey',
#   'overpriced',
#   'reluctant',
#   'compete',
#   'competing',
#   'dominate',
#   'dominating',
#   'refrain from',
#   'virtually',
#   'worthless',
#   'activate',
#   'permission',
#   'acknowledge',
#   'privacy',
#   'data-collection',
#   'status',
#   'willingness',
#   'congratulate',
#   'warlord',
#   'utilize',
#   'laying it on a bit thick',
#   'petitioned',
#   'discrimination',
#   'residents',
#   'superstitious',
#   'incorporated',
#   'nostalgic',
#   'manor',
#   'intimidating',
#   'committee',
#   'generous',
#   'spry',
#   'kendo',
#   'half-assing',
#   'a sight to behold',
#   'obediently',
#   'refined',
#   'sleeve',
#   'flutter',
#   'emphasizing',
#   'chatter',
#   'milling about',
#   'chiming',
#   'accompanies',
#   'entranced',
#   'spontaneously',
#   'regret',
#   'inherit',
#   'moron',
#   'gremlin',
#   'bickering',
#   'enshrined',
#   'raffle',
#   'katana',
#   'stabbed',
#   'gleams',
#   'luster',
#   'draw you in',
#   'dedicated',
#   'aforementioned',
#   'grin',
#   'grunts',
#   'exertion',
#   'draw the sword',
#   'macho',
#   'thighs',
#   'skeptical',
#   'stern glare',
#   'contestants',
#   'intimidating',
#   'charade',
#   'head priest',
#   'initial impression',
#   'bullseye',
#   'struck out',
#   'underestimate',
#   'flirt',
#   'boulder',
#   'hilt',
#   'crackle',
#   'firm grip',
#   'muttering',
#   'revenue',
#   'master',
#   'bewilderment',
#   'revenge',
#   'mere',
#   'spectacle',
#   'acquaintance',
#   'nonplussed',
#   'unfit',
#   'wield',
#   'tugged',
#   'styrofoam',
#   'interpretation',
#   'bestowed',
#   'majesty',
#   'lump',
#   'feat',
#   'deduction',
#   'insincere',
#   'provoking',
#   'ruckus',
#   'compensation',
#   'indulge',
#   'grief',
#   'stubborn',
#   'privileges',
#   'warped',
#   'pedestal',
#   'staring',
#   'starring',
#   'engaged',
#   'out of nowhere',
#   'betrothed',
#   'fiancée',
#   'fancy',
#   'interrupting',
#   'consequences',
#   'sleep a wink',
#   'principles',
#   'mortal',
#   'handy',
#   'retrospect',
#   'instincts',
#   'ingrained',
#   'retract',
#   'debate',
#   'feigning composure',
#   'resist',
#   'entertaining',
#   'intention',
#   'pajamas',
#   'accompany',
#   'doubt',
#   'aloof',
#   'freeloading',
#   'thud',
#   'blankly',
#   'mugged',
#   'preoccupied',
#   'squish',
#   'assent',
#   'exceptionally',
#   'consist of',
#   'fond',
#   'compromising',
#   'preferable',
#   'groggy',
#   'lingering',
#   'acquaintance',
#   'bodyguards',
#   'substitution',
#   'awkward',
#   'pardon',
#   'stubborn',
#   'ordeal',
#   'curt',
#   'grumbling',
#   'broadcast rerun',
#   'pathetic',
#   'particular',
#   'fraud',
#   'displeasing',
#   'appealing',
#   'persuade',
#   'investigate',
#   'rendezvous',
#   'pissed',
#   'ticked off',
#   'hypocritical',
#   'involuntary',
#   'inclines',
#   'rustling',
#   'clump',
#   'paralyze',
#   'twig',
#   'primal',
#   'treacherous',
#   'potential',
#   'graze',
#   'lance',
#   'tumbling',
#   'assailed',
#   'momentary',
#   'desperate',
#   'sheet',
#   'bandages',
#   'laceration',
#   'bruises',
#   'gawk',
#   'unsettling',
#   'sting',
#   'amiss',
#   'relieved',
#   'aghast',
#   'assure',
#   'ordeal',
#   'fuzzy',
#   'battered',
#   'banged up',
#   'shred',
#   'examined',
#   'breezy',
#   'strip',
#   'harassment',
#   'shrunk',
#   'groaning',
#   'insist',
#   'fright',
#   'incriminated',
#   'taint',
#   'unattended',
#   'concur',
#   'preface',
#   'regardless',
#   'dusk',
#   'indeed',
#   'suffice',
#   'sludge',
#   'indiscriminately',
#   'despises',
#   'hatred',
#   'denote',
#   'trail off',
#   'trait',
#   'exclusive',
#   'rumor',
#   'potency',
#   'beastly',
#   'dwelt',
#   'purifying',
#   'ominous',
#   'twinge',
#   'tend to',
#   'casual',
#   'formalities',
#   'sirloin',
#   'croquettes',
#   'certain',
#   'brood',
#   'approve',
#   'cabbage',
#   'freebie',
#   'labor',
#   'stealth',
#   'nobility',
#   "one's bearing",
#   'persona',
#   'dazzling',
#   'rehearsal',
#   'utmost',
#   'torn',
#   'sew',
#   'stitches',
#   'amateur',
#   'shoddy',
#   'involved',
#   'heirloom',
#   'burden',
#   'fanfare',
#   'stroll',
#   'shivers',
#   'bedridden',
#   'guarantee',
#   'casualties',
#   'ease',
#   'burden',
#   'stated',
#   'retrospect',
#   'drastic',
#   'celebrity',
#   'reverence',
#   'afflicted',
#   'plague',
#   'doomed',
#   'salvation',
#   'gladly',
#   'relinquish',
#   'resolve',
#   'screw this',
#   'pathetic',
#   'chivalry',
#   'pretense',
#   'cling',
#   'perish',
#   'deprecating',
#   'vitality',
#   'wane',
#   'inevitability',
#   'whim',
#   'volition',
#   'convince',
#   'groan',
#   'sulky',
#   'pedant',
#   'sash',
#   'faint',
#   'sentience',
#   'imbued',
#   'wreathed',
#   'falter',
#   'chill',
#   'tentacle',
#   'grooves',
#   "scramble to one's feet",
#   'send (someone) sprawling',
#   'deflecting',
#   'deftly',
#   'fend',
#   'reverie',
#   'scramble back',
#   'ferocious',
#   'writhe',
#   'thicket',
#   'chuckle',
#   'shabby',
#   'stiffly',
#   'shame',
#   'degenerate',
#   'reckless',
#   'leech',
#   'sidelines',
#   'grief',
#   'lectured',
#   'pretend',
#   'explicitly',
#   'non-perishable',
#   'cupboard',
#   ''],
#  ['n.小裝置／小玩意',
#   'v.低估',
#   'adj.未知的／未探索的',
#   'adj.有缺陷的／故障的',
#   'adj.注定失敗的',
#   'v.侵蝕／逐漸破壞',
#   'adv.直言不諱地',
#   'v.貶值',
#   'adj.過時的／淘汰的',
#   'n.選擇／替代方案',
#   'n.選擇（複數）',
#   'adj.中立的／不表態的',
#   'n.影響／後果',
#   'n.影響／後果（複數）',
#   'n.緊張關係／拉扯',
#   'v.成熟',
#   'adj.已成熟的',
#   'adj.可疑的／價值存疑的',
#   'n.先驅／開路者',
#   'idiom.冒險一試',
#   'idiom.閒置／積灰塵',
#   'phr.v.流行起來／被大眾接受',
#   'phr.掉進陷阱',
#   'phr.被套牢／甩不掉',
#   'phr.v.轉向',
#   'n.嘗鮮者／早期採用者',
#   'n.營收',
#   'n.營收（複數）',
#   'n.策略／手段',
#   'n./v.上市／發行',
#   'adv.大幅地',
#   'adv.此外',
#   'adv.迅速地',
#   'adj.謹慎的',
#   'n.小心／謹慎',
#   'adv.遺憾地',
#   'v.停產／停止支援',
#   'adj.已停產的／已停止支援的',
#   'adj.昂貴的',
#   'adj.定價過高的',
#   'adj.不情願的',
#   'v.競爭',
#   'adj.相互競爭的',
#   'v.主導／主宰',
#   'adj.佔優勢的',
#   'phr.v.克制／避免去做',
#   'adv.幾乎／實際上',
#   'adj.毫無價值的',
#   'v.啟動',
#   'n.許可',
#   'v.承認／告知',
#   'n.隱私',
#   'n.資料蒐集',
#   'n.地位／身份',
#   'n.意願',
#   'v.恭喜',
#   '軍閥（名詞）',
#   '利用；運用（動詞）',
#   '表現得有點太誇張；過度渲染',
#   '請願；正式請求（動詞）',
#   '歧視；差別待遇（名詞）',
#   '居民（名詞）',
#   '迷信的（形容詞）',
#   '納入；合併；使成為公司（動詞）',
#   '懷舊的（形容詞）',
#   '莊園；領地宅邸（名詞）',
#   '令人生畏的；嚇人的（形容詞）',
#   '委員會（名詞）',
#   '慷慨的；大方的（形容詞）',
#   '活潑敏捷的（形容詞）',
#   '劍道（名詞）',
#   '敷衍了事；馬馬虎虎地做（動詞）',
#   '值得一看的景象',
#   '順從地；服從地（副詞）',
#   '優雅的；精緻的（形容詞）',
#   '袖子（名詞）',
#   '飄動；拍動翅膀（動詞／名詞）',
#   '強調（動詞）',
#   '喋喋不休；閒聊（動詞／名詞）',
#   '四處閒逛；走來走去',
#   '發出鐘聲；插話附和（動詞）',
#   '陪伴；伴隨（動詞）',
#   '著迷的；被迷住的（形容詞）',
#   '自發地；自然地（副詞）',
#   '後悔；遺憾（動詞／名詞）',
#   '繼承（動詞）',
#   '笨蛋；蠢貨（名詞）',
#   '小精靈；搗蛋鬼（名詞）',
#   '爭吵；鬥嘴（動詞／名詞）',
#   '奉為神聖；正式載入（動詞）',
#   '抽獎（名詞／動詞）',
#   '武士刀（名詞）',
#   '刺；刺傷（動詞）',
#   '閃耀；微光（動詞／名詞）',
#   '光澤；光彩（名詞）',
#   '吸引你；使你投入',
#   '專注的；奉獻的（形容詞）',
#   '前述的；上述的（形容詞）',
#   '咧嘴笑（動詞／名詞）',
#   '咕噥聲；發出哼聲（動詞／名詞）',
#   '用力；勞累（名詞）',
#   '拔劍',
#   '大男人主義的；男子氣概強的（形容詞／名詞）',
#   '大腿（名詞）',
#   '懷疑的（形容詞）',
#   '嚴厲的瞪視（名詞）',
#   '參賽者（名詞）',
#   '令人生畏的；嚇人的（形容詞）',
#   '做戲；假裝（名詞）',
#   '大祭司；神職領袖（名詞）',
#   '第一印象',
#   '正中紅心；命中目標（名詞）',
#   '失敗；遭淘汰；三振出局',
#   '低估（動詞）',
#   '調情；打情罵俏（動詞／名詞）',
#   '巨石（名詞）',
#   '刀柄；劍柄（名詞）',
#   '劈啪作響（動詞／名詞）',
#   '牢固的握持',
#   '喃喃自語（動詞／名詞）',
#   '收入；營收（名詞）',
#   '大師；主人（名詞）／精通（動詞）',
#   '困惑；茫然（名詞）',
#   '報復；復仇（名詞／動詞）',
#   '僅僅的；只不過的（形容詞）',
#   '壯觀景象；奇觀（名詞）',
#   '熟人；認識的人（名詞）',
#   '困惑的；不知所措的（形容詞）',
#   '不適合的；不健康的（形容詞）',
#   '揮舞；使用（動詞）',
#   '拉扯；拖曳（動詞）',
#   '保麗龍；聚苯乙烯泡棉（名詞）',
#   '解釋；詮釋（名詞）',
#   '授予；賜予（動詞）',
#   '威嚴；陛下（名詞）',
#   '塊；腫塊（名詞）',
#   '壯舉；功績（名詞）',
#   '推論；扣除（名詞）',
#   '不真誠的；虛偽的（形容詞）',
#   '挑釁的；引起反應的（形容詞）',
#   '騷動；喧鬧（名詞）',
#   '補償；賠償（名詞）',
#   '縱容；沉溺於（動詞）',
#   '悲傷；悲痛（名詞）',
#   '固執的；頑強的（形容詞）',
#   '特權；特殊待遇（名詞）',
#   '扭曲的；變形的（形容詞）',
#   '基座；（比喻）受人崇拜的地位（名詞）',
#   '盯著看（動詞）',
#   '主演；擔任主角（動詞）',
#   '已訂婚的；忙碌的；投入的（形容詞）',
#   '突然地；不知從何處地',
#   '已訂婚的；未婚夫／未婚妻（形容詞／名詞）',
#   '未婚妻（名詞）',
#   '喜愛；想要（動詞）華麗的；高級的（形容詞）',
#   '打斷；中斷（動詞）',
#   '後果（名詞）',
#   '睡著片刻；闔眼休息',
#   '原則；信念（名詞）',
#   '終有一死的；凡人的（形容詞／名詞）',
#   '方便的；有用的（形容詞）',
#   '回顧；追溯（名詞）',
#   '本能；直覺（名詞）',
#   '根深蒂固的（形容詞）',
#   '撤回；收回（動詞）',
#   '辯論；討論（名詞／動詞）',
#   '假裝鎮定',
#   '抵抗；忍住（動詞）',
#   '有趣的；娛樂性的（形容詞）',
#   '意圖；目的（名詞）',
#   '睡衣（名詞）',
#   '陪伴；伴隨（動詞）',
#   '懷疑（動詞／名詞）',
#   '冷淡的；疏遠的（形容詞）',
#   '白吃白喝；佔便宜（動詞／名詞）',
#   '砰的一聲；重擊聲（名詞）',
#   '茫然地；呆呆地（副詞）',
#   '搶劫（動詞）',
#   '心不在焉的；全神貫注於某事的（形容詞）',
#   '壓扁；擠壓（動詞／名詞）',
#   '同意；贊成（動詞／名詞）',
#   '特別地；異常地（副詞）',
#   '由……組成',
#   '喜愛的；喜歡的（形容詞）',
#   '妥協的；有損形象的（形容詞）',
#   '較好的；更可取的（形容詞）',
#   '昏昏沉沉的（形容詞）',
#   '持續存在的；流連不去的（形容詞）',
#   '熟人；認識的人（名詞）',
#   '保鑣（名詞）',
#   '替代；代換（名詞）',
#   '尷尬的；笨拙的（形容詞）',
#   '原諒；赦免（動詞／名詞）',
#   '固執的（形容詞）',
#   '嚴酷考驗；磨難（名詞）',
#   '簡短無禮的（形容詞）',
#   '抱怨；發牢騷（動詞／名詞）',
#   '重播節目（名詞）',
#   '可憐的；糟糕的（形容詞）',
#   '特定的；特別的（形容詞）',
#   '詐騙；騙子（名詞）',
#   '令人不快的（形容詞）',
#   '吸引人的（形容詞）',
#   '說服（動詞）',
#   '調查（動詞）',
#   '會面；約會地點（名詞）',
#   '生氣的（形容詞，較口語）',
#   '惱火的；生氣的（形容詞）',
#   '虛偽的；偽善的（形容詞）',
#   '非自願的；不由自主的（形容詞）',
#   '傾向於；斜坡（動詞／名詞）',
#   '沙沙作響（動詞／名詞）',
#   '一叢；一團（名詞）',
#   '使癱瘓；使無法行動（動詞）',
#   '細枝；嫩枝（名詞）',
#   '原始的；本能的（形容詞）',
#   '危險的；背信棄義的（形容詞）',
#   '潛力；潛在的（名詞／形容詞）',
#   '擦傷；吃草（動詞）',
#   '長矛（名詞）',
#   '翻滾；跌倒（動詞）',
#   '猛烈攻擊；抨擊（動詞）',
#   '短暫的；瞬間的（形容詞）',
#   '絕望的；孤注一擲的（形容詞）',
#   '床單；薄片；紙張（名詞）',
#   '繃帶（名詞）',
#   '撕裂傷（名詞）',
#   '瘀青；挫傷（名詞）',
#   '呆看；目瞪口呆地盯著看（動詞）',
#   '令人不安的（形容詞）',
#   '刺痛；叮咬（動詞／名詞）',
#   '不對勁的；有問題的（形容詞）',
#   '鬆了一口氣的；安心的（形容詞）',
#   '驚駭的；嚇呆的（形容詞）',
#   '向……保證；使確信（動詞）',
#   '磨難；嚴酷考驗（名詞）',
#   '模糊的；毛茸茸的（形容詞）',
#   '傷痕累累的；破舊的（形容詞）',
#   '受傷的；撞壞的（形容詞）',
#   '碎片；撕碎（名詞／動詞）',
#   '檢查；檢驗（動詞）',
#   '微風徐徐的；輕鬆愉快的（形容詞）',
#   '長條；剝除；脫去（名詞／動詞）',
#   '騷擾（名詞）',
#   '縮小；縮水（動詞）',
#   '呻吟；抱怨（動詞／名詞）',
#   '堅持；堅決要求（動詞）',
#   '恐懼；驚嚇（名詞）',
#   '使牽連入罪；指控（動詞）',
#   '玷污；污染（動詞／名詞）',
#   '無人照顧的；無人看管的（形容詞）',
#   '同意；意見一致（動詞）',
#   '前言；作為開場白（名詞／動詞）',
#   '不管怎樣；無論如何（副詞）',
#   '黃昏（名詞）',
#   '確實；的確（副詞）',
#   '足夠；足以（動詞）',
#   '爛泥；污泥（名詞）',
#   '不加區分地；不分青紅皂白地（副詞）',
#   '鄙視；厭惡（動詞）',
#   '仇恨（名詞）',
#   '表示；象徵（動詞）',
#   '逐漸變小聲；漸漸停止',
#   '特徵；性格特質（名詞）',
#   '獨有的；排他的（形容詞）',
#   '謠言（名詞）',
#   '效力；力量（名詞）',
#   '野獸般的；可怕的（形容詞）',
#   '居住；停留於（動詞）',
#   '淨化；潔淨（動詞）',
#   '不祥的；不好的預兆的（形容詞）',
#   '一陣刺痛；一絲感覺（名詞）',
#   '傾向於；往往會',
#   '隨意的；非正式的（形容詞）',
#   '禮節；正式程序（名詞）',
#   '沙朗牛排（名詞）',
#   '可樂餅（名詞）',
#   '確定的；某個的（形容詞）',
#   '沉思；孵蛋（動詞）',
#   '同意；批准（動詞）',
#   '高麗菜；捲心菜（名詞）',
#   '免費贈品（名詞）',
#   '勞動；工作（名詞／動詞）',
#   '隱密行動；潛行（名詞）',
#   '貴族階級；高尚品格（名詞）',
#   '某人的儀態；舉止（名詞）',
#   '人物形象；人格面具（名詞）',
#   '耀眼的；令人驚艷的（形容詞）',
#   '排練（名詞）',
#   '最大的；極度的（形容詞）',
#   '撕裂的；糾結的（形容詞）',
#   '縫製（動詞）',
#   '縫線；縫合針（名詞）',
#   '業餘愛好者；業餘的（名詞／形容詞）',
#   '粗製濫造的；劣質的（形容詞）',
#   '涉及的；複雜的（形容詞）',
#   '傳家寶（名詞）',
#   '負擔；重擔（名詞／動詞）',
#   '盛大宣傳；號角齊鳴（名詞）',
#   '散步（動詞／名詞）',
#   '顫抖；寒顫（名詞）',
#   '臥病在床的（形容詞）',
#   '保證；擔保（名詞／動詞）',
#   '傷亡人數；受害者（名詞）',
#   '減輕；容易（動詞／名詞）',
#   '負擔；重擔（名詞／動詞）',
#   '陳述；說明（動詞）',
#   '回顧；追溯（名詞）',
#   '激烈的；極端的（形容詞）',
#   '名人（名詞）',
#   '敬畏；尊敬（名詞）',
#   '受折磨的；受苦的（形容詞）',
#   '瘟疫；困擾（名詞／動詞）',
#   '註定失敗的；注定滅亡的（形容詞）',
#   '救贖；拯救（名詞）',
#   '樂意地；高興地（副詞）',
#   '放棄；交出（動詞）',
#   '決心；解決（名詞／動詞）',
#   '去他的；我不幹了',
#   '可憐的；糟糕的（形容詞）',
#   '騎士精神（名詞）',
#   '假裝；藉口（名詞）',
#   '緊抓；依戀（動詞）',
#   '死亡；毀滅（動詞）',
#   '自貶的；反對的（形容詞）',
#   '活力；生命力（名詞）',
#   '衰退；減弱（動詞）',
#   '必然性（名詞）',
#   '一時興起；心血來潮（名詞）',
#   '意志；自主決定（名詞）',
#   '說服；使相信（動詞）',
#   '呻吟；抱怨（動詞／名詞）',
#   '鬧彆扭的；悶悶不樂的（形容詞）',
#   '學究；賣弄學問的人（名詞）',
#   '腰帶；肩帶（名詞）',
#   '昏倒；微弱的（動詞／形容詞）',
#   '知覺能力；感知力（名詞）',
#   '使充滿；灌輸（動詞）',
#   '環繞；覆蓋（動詞）',
#   '遲疑；蹣跚（動詞）',
#   '寒冷；使冷卻（名詞／動詞）',
#   '觸手（名詞）',
#   '凹槽；溝紋（名詞）',
#   '匆忙站起來',
#   '把（某人）撞倒在地',
#   '使偏轉；轉移（動詞）',
#   '熟練地；靈巧地（副詞）',
#   '抵擋；應付（動詞）',
#   '白日夢；幻想（名詞）',
#   '慌忙退後',
#   '兇猛的；殘暴的（形容詞）',
#   '扭動；翻滾掙扎（動詞）',
#   '灌木叢（名詞）',
#   '輕聲笑（動詞／名詞）',
#   '破舊的；寒酸的（形容詞）',
#   '僵硬地；拘謹地（副詞）',
#   '羞愧；恥辱（名詞）',
#   '墮落的；退化（形容詞／動詞）',
#   '魯莽的；不顧後果的（形容詞）',
#   '水蛭；吸血鬼般的人（名詞）',
#   '場邊；旁觀位置（名詞）',
#   '悲傷；悲痛（名詞）',
#   '訓斥；講授（動詞）',
#   '假裝（動詞）',
#   '明確地；直白地（副詞）',
#   '不易腐壞的；耐存放的（形容詞）',
#   '櫥櫃；碗櫥（名詞）'])

# %%
import torch

a = torch.randn(10,10)
b = a@a
print(b)
# Out:
# tensor([[ 1.2094,  1.1421, -2.5339, -1.3569,  0.8769,  0.9777, -2.3846,  4.0748,
#          -1.4810,  6.6267],
#         [ 0.6607,  1.3511,  5.2748,  1.9337, -4.4500,  1.8374,  0.5350, -9.7903,
#          -2.1924, -8.6457],
#         [ 1.0726, -3.0102,  1.7130, -1.2065,  0.5237, -3.0905,  0.9425, -1.1867,
#           1.0576, -5.1369],
#         [ 1.4559, -3.6299,  0.9335,  1.5782, -0.1289,  1.9662, -2.4951,  3.0091,
#           1.9189, -0.0332],
#         [-3.3563,  1.3173,  2.9904,  0.5836,  0.2202,  0.0864,  1.4566, -4.4502,
#          -3.0456,  1.3235],
#         [-0.7367, -1.7452,  0.3376, -0.7522,  2.4351,  2.2863, -4.6936,  3.1024,
#          -0.3708,  2.8969],
#         [ 0.5357, -5.6755,  4.6611,  3.1734,  1.3792, -0.2230, -1.2430,  5.6741,
#          -1.3295,  2.6098],
#         [-1.0601,  3.4847,  0.1058,  0.7335,  0.9581, -0.4606, -0.9600,  0.2939,
#          -6.6803,  5.6475],
#         [-1.2984,  2.5202, -0.9297,  1.8660, -0.0781,  0.7417, -4.4286,  0.3257,
#          -3.5714,  5.5447],
#         [-2.7226, -2.0320,  2.6785,  3.1279, -1.8699, -3.0085,  1.8123, -4.2453,
#          -1.6094, -4.7908]])

# %%
import random
def dataset_len():
  return len(english)


def get_random_word():
  len = dataset_len()
  r = random.randint(0,len-1)
  return english[r],chinese[r]


def get_word(idx):
  return english[idx],chinese[idx]


def gen_que(idx):
  #生成除了idx外的三個選項，並和正確選項包在一起回傳
  ans = get_word(idx)
  pool = set(range(0,dataset_len()))
  pool.remove(idx)
  options = random.sample(sorted(pool),3)
  options.append(idx)
  random.shuffle(options)
  return idx,options

# %%
print("單字總數：", dataset_len())
en, zh = get_random_word()
print("隨機單字：", en)
print("中文解釋：", zh)
# Out:
# 單字總數： 368
# 隨機單字： manor
# 中文解釋： 莊園；領地宅邸（名詞）

# %%
order = list(range(0,dataset_len()))
random.shuffle(order)

correct = 0
wrong = 0

for i in order:
  e,c = get_word(i)

  print(f"{e}的中文是以下哪個? (輸入<0的數字離開)")
  ans,option = gen_que(i)
  print(chinese[option[0]],chinese[option[1]],chinese[option[2]],chinese[option[3]],sep=',')
  player_choice = int(input())
  # print(option[player_choice],i)
  if player_choice <= 0:
    break
  if option[player_choice] == i+1:
    print("正確")
    correct+=1
  else:
    print("錯誤")
    wrong+=1

print(f"正確:{correct}, 錯誤:{wrong}")
# Out:
# assent的中文是以下哪個? (輸入<0的數字離開)
# 傷亡人數；受害者（名詞）,同意；贊成（動詞／名詞）,櫥櫃；碗櫥（名詞）,n.嘗鮮者／早期採用者
# -1
# 正確:0, 錯誤:0

# %%
# TODO: I don't know
